# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
radii = 0.345
sdf_values = np.random.randn(1000, 1).astype(np.float32)
labels = radii > sdf_values

# %% [markdown]
# # If you don't scale the sigmoid, it won't recover the right threshold

# %%
tf.reset_default_graph()
s = tf.Session()

tf_labels = tf.placeholder(tf.float32, shape=(None, 1), name='labels')
tf_radius = tf.get_variable('radius', initializer=10.0)
tf_sdfs = tf.placeholder(tf.float32, shape=(None, 1), name='sdfs')
logits = 1*(tf_radius - tf_sdfs)
loss_op = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=tf_labels))
optimizer = tf.train.AdamOptimizer(learning_rate=0.01)
gradients, variables = zip(*optimizer.compute_gradients(loss_op))
gradients, _ = tf.clip_by_global_norm(gradients, 5)
opt = optimizer.apply_gradients(zip(gradients, variables))
rgrad = tf.gradients(loss_op, tf_radius)

s.run(tf.global_variables_initializer())
loss = s.run([loss_op], feed_dict={tf_sdfs: sdf_values, tf_labels: labels})

for i in range(5000):
    loss, rad, rrg, _ = s.run([loss_op, tf_radius, rgrad, opt], feed_dict={tf_sdfs: sdf_values, tf_labels: labels})
    if abs(rad - radii) < 0.003:
        print("success!")
        break
print("done.")
# Out:
# (3.1957052, 10.0, [0.35592815])
# (3.1601114, 9.899998, [0.3559206])
# (3.1245193, 9.799995, [0.35591227])
# (3.0889275, 9.699993, [0.35590306])
# (3.0533373, 9.599993, [0.35589284])
# (3.0177515, 9.5, [0.3558815])
# (2.9821665, 9.400007, [0.35586908])
# (2.9465828, 9.3000145, [0.35585535])
# (2.9110005, 9.200022, [0.35584012])
# (2.8754206, 9.100031, [0.3558233])
# (2.8398452, 9.000048, [0.35580474])
# (2.8042715, 8.900064, [0.35578424])
# (2.7687001, 8.800081, [0.35576153])
# (2.7331347, 8.700108, [0.35573646])
# (2.6975718, 8.600134, [0.35570878])
# (2.662015, 8.500168, [0.3556782])
# (2.6264613, 8.400204, [0.35564438])
# (2.5909147, 8.300249, [0.35560703])
# (2.555374, 8.200299, [0.3555658])
# (2.5198398, 8.100356, [0.35552016])
# (2.4843135, 8.000422, [0.35546982])
# (2.4487953, 7.900496, [0.35541418])
# (2.4132872, 7.8005805, [0.3553527])
# (2.3777893, 7.700676, [0.3552848])
# (2.3423028, 7.600784, [0.3552098])
# (2.3068297, 7.5009065, [0.35512698])
# (2.2713706, 7.401045, [0.3550355])
# (2.2359269, 7.3012, [0.35493448])
# (2.200501, 7.2013745, [0.35482293])
# (2.165094, 7.10157, [0.3546998])
# (2.1297085, 7.0017896, [0.35456383])
# (2.0943472, 6.902036, [0.35441378])
# (2.0590115, 6.802312, [0.35424814])
# (2.0237048, 6.70262, [0.35406533])
# (1.9884301, 6.602965, [0.35386363])
# (1.9531908, 6.5033493, [0.3536411])
# (1.9179906, 6.4037786, [0.35339564])
# (1.8828332, 6.304257, [0.35312495])
# (1.8477236, 6.2047906, [0.35282654])
# (1.8126668, 6.1053843, [0.35249764])
# (1.7776678, 6.006046, [0.3521352])
# (1.742733, 5.906782, [0.35173595])
# (1.707869, 5.807601, [0.35129628])
# (1.6730822, 5.7085094, [0.3508123])
# (1.6383811, 5.6095195, [0.35027975])
# (1.6037747, 5.510641, [0.34969404])
# (1.5692717, 5.4118853, [0.34905016])
# (1.5348823, 5.313265, [0.3483427])
# (1.5006189, 5.214795, [0.3475659])
# (1.4664925, 5.11649, [0.34671348])
# (1.4325169, 5.0183663, [0.3457787])
# (1.3987063, 4.9204426, [0.3447545])
# (1.3650763, 4.8227386, [0.34363312])
# (1.3316442, 4.7252765, [0.34240657])
# (1.2984276, 4.6280804, [0.34106627])
# (1.2654462, 4.5311747, [0.33960328])
# (1.2327212, 4.434589, [0.33800817])
# (1.2002745, 4.3383512, [0.33627123])
# (1.16813, 4.242495, [0.3343824])
# (1.136313, 4.147055, [0.33233136])
# (1.1048506, 4.05207, [0.33010763])
# (1.0737705, 3.9575791, [0.3277008])
# (1.0431023, 3.863625, [0.32510024])
# (1.0128765, 3.7702544, [0.32229584])
# (0.983125, 3.6775148, [0.31927767])
# (0.9538805, 3.5854573, [0.31603634])
# (0.92517614, 3.4941359, [0.31256318])
# (0.897046, 3.403607, [0.30885047])
# (0.8695246, 3.3139298, [0.30489156])
# (0.8426456, 3.2251647, [0.30068105])
# (0.81644267, 3.1373754, [0.29621515])
# (0.7909491, 3.0506265, [0.29149178])
# (0.7661959, 2.9649842, [0.2865107])
# (0.7422137, 2.8805158, [0.28127366])
# (0.7190303, 2.7972891, [0.2757847])
# (0.6966715, 2.715372, [0.2700501])
# (0.67516005, 2.6348329, [0.26407844])
# (0.6545156, 2.5557375, [0.2578806])
# (0.6347541, 2.4781513, [0.2514697])
# (0.61588824, 2.4021382, [0.24486127])
# (0.59792596, 2.3277583, [0.23807274])
# (0.5808714, 2.2550695, [0.23112342])
# (0.56472445, 2.1841264, [0.22403441])
# (0.5494804, 2.1149786, [0.21682814])
# (0.5351303, 2.0476708, [0.20952801])
# (0.52166116, 1.9822439, [0.20215845])
# (0.5090558, 1.9187325, [0.19474418])
# (0.4972938, 1.8571665, [0.18731022])
# (0.48635072, 1.7975686, [0.17988116])
# (0.4761995, 1.7399564, [0.17248136])
# (0.4668103, 1.6843411, [0.1651342])
# (0.458151, 1.6307279, [0.15786216])
# (0.45018795, 1.5791162, [0.15068641])
# (0.44288585, 1.5294993, [0.14362666])
# (0.4362086, 1.4818648, [0.13670102])
# (0.43011972, 1.436195, [0.1299259])
# (0.4245824, 1.3924668, [0.1233159])
# (0.41956005, 1.350652, [0.116883725])
# (0.41501686, 1.3107188, [0.11064039])
# (0.4109176, 1.2726308, [0.10459499])
# (0.40722832, 1.2363478, [0.09875485])
# (0.40391618, 1.2018268, [0.09312571])
# (0.40094978, 1.1690217, [0.08771158])
# (0.39829943, 1.137884, [0.08251504])
# (0.39593682, 1.1083632, [0.07753727])
# (0.3938356, 1.0804065, [0.07277806])
# (0.3919709, 1.0539613, [0.068236254])
# (0.39031982, 1.0289729, [0.06390953])
# (0.38886085, 1.0053859, [0.059794582])
# (0.3875744, 0.9831456, [0.055887517])
# (0.38644236, 0.96219647, [0.05218358])
# (0.3854482, 0.9424835, [0.048677485])
# (0.38457683, 0.9239522, [0.045363516])
# (0.3838145, 0.9065486, [0.042235464])
# (0.38314894, 0.8902198, [0.03928691])
# (0.3825688, 0.874914, [0.036511213])
# (0.38206413, 0.86058015, [0.03390148])
# (0.38162595, 0.84716874, [0.03145078])
# (0.38124603, 0.83463174, [0.029152155])
# (0.3809173, 0.8229225, [0.026998641])
# (0.38063326, 0.811996, [0.024983335])
# (0.38038835, 0.80180854, [0.02309941])
# (0.3801775, 0.79231834, [0.021340167])
# (0.3799962, 0.7834851, [0.019699058])
# (0.37984067, 0.77527016, [0.01816968])
# (0.37970743, 0.7676365, [0.016745828])
# (0.37959343, 0.7605488, [0.015421516])
# (0.37949604, 0.75397336, [0.014190957])
# (0.37941304, 0.74787796, [0.0130485445])
# (0.37934235, 0.7422321, [0.011988955])
# (0.3792823, 0.73700666, [0.011007052])
# (0.3792313, 0.73217416, [0.01009794])
# (0.37918806, 0.7277085, [0.009256963])
# (0.37915152, 0.723585, [0.008479666])
# (0.37912065, 0.7197807, [0.0077619012])
# (0.37909457, 0.71627337, [0.0070996317])
# (0.3790726, 0.71304226, [0.0064890636])
# (0.37905413, 0.7100678, [0.005926611])
# (0.3790386, 0.7073318, [0.0054089194])
# (0.37902564, 0.70481706, [0.004932826])
# (0.3790147, 0.70250756, [0.0044953567])
# (0.3790056, 0.7003879, [0.004093654])
# (0.37899804, 0.6984441, [0.003725118])
# (0.3789917, 0.6966627, [0.0033872344])
# (0.3789864, 0.6950315, [0.0030777263])
# (0.37898204, 0.6935392, [0.0027944741])
# (0.3789784, 0.6921748, [0.0025354195])
# (0.3789754, 0.6909283, [0.002298684])
# (0.3789729, 0.6897903, [0.0020825085])
# (0.37897083, 0.68875223, [0.0018852614])
# (0.37896913, 0.68780607, [0.0017054428])
# (0.3789677, 0.6869441, [0.0015415959])
# (0.3789666, 0.6861597, [0.0013924558])
# (0.37896568, 0.6854463, [0.0012568117])
# (0.37896484, 0.6847981, [0.001133537])
# (0.37896428, 0.6842095, [0.0010215831])
# (0.37896374, 0.6836754, [0.0009199807])
# (0.3789633, 0.6831912, [0.0008278561])
# (0.37896296, 0.68275243, [0.00074437726])
# (0.3789627, 0.6823552, [0.0006687965])
# (0.37896246, 0.68199605, [0.00060044474])
# (0.37896228, 0.68167144, [0.0005386695])
# (0.3789621, 0.6813783, [0.00048287841])
# (0.378962, 0.6811137, [0.0004325189])
# (0.3789619, 0.6808751, [0.00038710318])
# (0.3789618, 0.6806601, [0.0003461776])
# (0.37896177, 0.68046665, [0.000309346])
# (0.37896168, 0.68029267, [0.00027622387])
# (0.3789617, 0.6801362, [0.0002464375])
# (0.37896162, 0.6799957, [0.00021969248])
# (0.3789616, 0.6798696, [0.00019567902])
# (0.3789616, 0.6797565, [0.0001741529])
# (0.3789616, 0.6796552, [0.00015485799])
# (0.3789615, 0.6795645, [0.00013758673])
# (0.37896153, 0.6794834, [0.00012215145])
# (0.37896147, 0.679411, [0.000108362874])
# (0.3789615, 0.6793463, [9.604939e-05])
# (0.3789615, 0.6792886, [8.5063744e-05])
# (0.3789615, 0.67923707, [7.5245975e-05])
# (0.37896153, 0.6791913, [6.652856e-05])
# (0.37896147, 0.6791505, [5.8765057e-05])
# (0.37896147, 0.6791143, [5.1863026e-05])
# (0.37896147, 0.6790821, [4.5733992e-05])
# (0.3789615, 0.67905354, [4.0297164e-05])
# (0.37896147, 0.6790282, [3.5475474e-05])
# (0.3789615, 0.67900574, [3.119558e-05])
# (0.37896147, 0.67898583, [2.7404632e-05])
# (0.37896147, 0.67896825, [2.4055596e-05])
# (0.37896147, 0.67895263, [2.1081418e-05])
# (0.37896147, 0.6789389, [1.846999e-05])
# (0.37896147, 0.6789269, [1.6179867e-05])
# (0.3789615, 0.6789162, [1.4148885e-05])
# (0.37896147, 0.67890686, [1.23670325e-05])
# (0.3789615, 0.67889863, [1.0798918e-05])
# (0.37896147, 0.67889136, [9.413809e-06])
# (0.37896147, 0.67888504, [8.211238e-06])
# (0.37896147, 0.67887944, [7.146038e-06])
# (0.37896147, 0.67887455, [6.21262e-06])
# (0.37896147, 0.67887026, [5.393289e-06])
# (0.37896147, 0.67886657, [4.6927016e-06])
# (0.37896144, 0.6788633, [4.069181e-06])
# (0.37896147, 0.67886037, [3.511319e-06])
# (0.37896147, 0.678858, [3.0582305e-06])
# (0.37896147, 0.6788557, [2.625864e-06])
# (0.37896147, 0.6788539, [2.285e-06])
# (0.37896147, 0.67885214, [1.9469298e-06])
# (0.37896147, 0.6788508, [1.6950071e-06])
# (0.37896147, 0.67884964, [1.46823e-06])
# (0.37896147, 0.67884845, [1.2416858e-06])
# (0.37896147, 0.67884743, [1.0479707e-06])
# (0.37896147, 0.67884684, [9.3574636e-07])
# (0.37896147, 0.67884624, [8.2165934e-07])
# (0.37896147, 0.67884564, [7.082708e-07])
# (0.37896147, 0.67884505, [5.958136e-07])
# (0.37896147, 0.67884445, [4.800968e-07])
# (0.37896147, 0.67884386, [3.676396e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.6788435, [2.9895455e-07])
# (0.37896147, 0.6788435, [2.9895455e-07])
# (0.37896147, 0.6788435, [2.9895455e-07])
# (0.37896147, 0.6788435, [2.9895455e-07])
# (0.37896147, 0.6788435, [2.9895455e-07])
# (0.37896147, 0.6788435, [2.9895455e-07])
# (0.37896147, 0.67884344, [2.880115e-07])
# (0.37896147, 0.67884344, [2.880115e-07])
# (0.37896147, 0.67884344, [2.880115e-07])
# (0.37896147, 0.67884344, [2.880115e-07])
# (0.37896147, 0.67884344, [2.880115e-07])
# (0.37896147, 0.67884344, [2.880115e-07])
# (0.37896147, 0.67884344, [2.880115e-07])
# (0.37896144, 0.6788434, [2.7706847e-07])
# (0.37896144, 0.6788434, [2.7706847e-07])
# (0.37896144, 0.6788434, [2.7706847e-07])
# (0.37896144, 0.6788434, [2.7706847e-07])
# (0.37896144, 0.6788434, [2.7706847e-07])
# (0.37896144, 0.6788434, [2.7706847e-07])
# (0.37896144, 0.6788434, [2.7706847e-07])
# (0.37896144, 0.6788434, [2.7706847e-07])
# (0.3789615, 0.6788433, [2.651941e-07])
# (0.3789615, 0.6788433, [2.651941e-07])
# (0.3789615, 0.6788433, [2.651941e-07])
# (0.3789615, 0.6788433, [2.651941e-07])
# (0.3789615, 0.6788433, [2.651941e-07])
# (0.3789615, 0.6788433, [2.651941e-07])
# (0.3789615, 0.6788433, [2.651941e-07])
# (0.3789615, 0.6788433, [2.651941e-07])
# (0.3789615, 0.67884326, [2.5401823e-07])
# (0.3789615, 0.67884326, [2.5401823e-07])
# (0.3789615, 0.67884326, [2.5401823e-07])
# (0.3789615, 0.67884326, [2.5401823e-07])
# (0.3789615, 0.67884326, [2.5401823e-07])
# (0.3789615, 0.67884326, [2.5401823e-07])
# (0.3789615, 0.67884326, [2.5401823e-07])
# (0.3789615, 0.67884326, [2.5401823e-07])
# (0.3789615, 0.6788432, [2.423767e-07])
# (0.3789615, 0.6788432, [2.423767e-07])
# (0.3789615, 0.6788432, [2.423767e-07])
# (0.3789615, 0.6788432, [2.423767e-07])
# (0.3789615, 0.6788432, [2.423767e-07])
# (0.3789615, 0.6788432, [2.423767e-07])
# (0.3789615, 0.6788432, [2.423767e-07])
# (0.3789615, 0.6788432, [2.423767e-07])
# (0.3789615, 0.6788432, [2.423767e-07])
# (0.3789615, 0.67884314, [2.3003668e-07])
# (0.3789615, 0.67884314, [2.3003668e-07])
# (0.3789615, 0.67884314, [2.3003668e-07])
# (0.3789615, 0.67884314, [2.3003668e-07])
# (0.3789615, 0.67884314, [2.3003668e-07])
# (0.3789615, 0.67884314, [2.3003668e-07])
# (0.3789615, 0.67884314, [2.3003668e-07])
# (0.3789615, 0.67884314, [2.3003668e-07])
# (0.3789615, 0.67884314, [2.3003668e-07])
# (0.3789615, 0.67884314, [2.3003668e-07])
# (0.3789615, 0.6788431, [2.2025779e-07])
# (0.3789615, 0.6788431, [2.2025779e-07])
# (0.3789615, 0.6788431, [2.2025779e-07])
# (0.3789615, 0.6788431, [2.2025779e-07])
# (0.3789615, 0.6788431, [2.2025779e-07])
# (0.3789615, 0.6788431, [2.2025779e-07])
# (0.3789615, 0.6788431, [2.2025779e-07])
# (0.3789615, 0.6788431, [2.2025779e-07])
# (0.3789615, 0.678843, [2.0978041e-07])
# (0.3789615, 0.678843, [2.0978041e-07])
# (0.3789615, 0.678843, [2.0978041e-07])
# (0.3789615, 0.678843, [2.0978041e-07])
# (0.3789615, 0.678843, [2.0978041e-07])
# (0.3789615, 0.678843, [2.0978041e-07])
# (0.3789615, 0.678843, [2.0978041e-07])
# (0.3789615, 0.678843, [2.0978041e-07])
# (0.3789615, 0.678843, [2.0978041e-07])
# (0.3789615, 0.678843, [2.0978041e-07])
# (0.37896144, 0.67884296, [1.9767322e-07])
# (0.37896144, 0.67884296, [1.9767322e-07])
# (0.37896144, 0.67884296, [1.9767322e-07])
# (0.37896144, 0.67884296, [1.9767322e-07])
# (0.37896144, 0.67884296, [1.9767322e-07])
# (0.37896144, 0.67884296, [1.9767322e-07])
# (0.37896144, 0.67884296, [1.9767322e-07])
# (0.37896144, 0.67884296, [1.9767322e-07])
# (0.37896144, 0.67884296, [1.9767322e-07])
# (0.37896144, 0.67884296, [1.9767322e-07])
# (0.37896144, 0.67884296, [1.9767322e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# done.

# %% [markdown]
# # If you  scale the sigmoid, it works!

# %%
tf.reset_default_graph()
s = tf.Session()

tf_labels = tf.placeholder(tf.float32, shape=(None, 1), name='labels')
tf_radius = tf.get_variable('radius', initializer=10.0)
tf_sdfs = tf.placeholder(tf.float32, shape=(None, 1), name='sdfs')
logits = 100*(tf_radius - tf_sdfs)
loss_op = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=tf_labels))
optimizer = tf.train.AdamOptimizer(learning_rate=0.01)
gradients, variables = zip(*optimizer.compute_gradients(loss_op))
gradients, _ = tf.clip_by_global_norm(gradients, 5)
opt = optimizer.apply_gradients(zip(gradients, variables))
rgrad = tf.gradients(loss_op, tf_radius)

s.run(tf.global_variables_initializer())
loss = s.run([loss_op], feed_dict={tf_sdfs: sdf_values, tf_labels: labels})

for i in range(5000):
    loss, rad, rrg, _ = s.run([loss_op, tf_radius, rgrad, opt], feed_dict={tf_sdfs: sdf_values, tf_labels: labels})
    if abs(rad - radii) < 0.003:
        print("success!")
        break
print("done.")
# Out:
# (3.1957052, 10.0, [0.35592815])
# (3.1601114, 9.899998, [0.3559206])
# (3.1245193, 9.799995, [0.35591227])
# (3.0889275, 9.699993, [0.35590306])
# (3.0533373, 9.599993, [0.35589284])
# (3.0177515, 9.5, [0.3558815])
# (2.9821665, 9.400007, [0.35586908])
# (2.9465828, 9.3000145, [0.35585535])
# (2.9110005, 9.200022, [0.35584012])
# (2.8754206, 9.100031, [0.3558233])
# (2.8398452, 9.000048, [0.35580474])
# (2.8042715, 8.900064, [0.35578424])
# (2.7687001, 8.800081, [0.35576153])
# (2.7331347, 8.700108, [0.35573646])
# (2.6975718, 8.600134, [0.35570878])
# (2.662015, 8.500168, [0.3556782])
# (2.6264613, 8.400204, [0.35564438])
# (2.5909147, 8.300249, [0.35560703])
# (2.555374, 8.200299, [0.3555658])
# (2.5198398, 8.100356, [0.35552016])
# (2.4843135, 8.000422, [0.35546982])
# (2.4487953, 7.900496, [0.35541418])
# (2.4132872, 7.8005805, [0.3553527])
# (2.3777893, 7.700676, [0.3552848])
# (2.3423028, 7.600784, [0.3552098])
# (2.3068297, 7.5009065, [0.35512698])
# (2.2713706, 7.401045, [0.3550355])
# (2.2359269, 7.3012, [0.35493448])
# (2.200501, 7.2013745, [0.35482293])
# (2.165094, 7.10157, [0.3546998])
# (2.1297085, 7.0017896, [0.35456383])
# (2.0943472, 6.902036, [0.35441378])
# (2.0590115, 6.802312, [0.35424814])
# (2.0237048, 6.70262, [0.35406533])
# (1.9884301, 6.602965, [0.35386363])
# (1.9531908, 6.5033493, [0.3536411])
# (1.9179906, 6.4037786, [0.35339564])
# (1.8828332, 6.304257, [0.35312495])
# (1.8477236, 6.2047906, [0.35282654])
# (1.8126668, 6.1053843, [0.35249764])
# (1.7776678, 6.006046, [0.3521352])
# (1.742733, 5.906782, [0.35173595])
# (1.707869, 5.807601, [0.35129628])
# (1.6730822, 5.7085094, [0.3508123])
# (1.6383811, 5.6095195, [0.35027975])
# (1.6037747, 5.510641, [0.34969404])
# (1.5692717, 5.4118853, [0.34905016])
# (1.5348823, 5.313265, [0.3483427])
# (1.5006189, 5.214795, [0.3475659])
# (1.4664925, 5.11649, [0.34671348])
# (1.4325169, 5.0183663, [0.3457787])
# (1.3987063, 4.9204426, [0.3447545])
# (1.3650763, 4.8227386, [0.34363312])
# (1.3316442, 4.7252765, [0.34240657])
# (1.2984276, 4.6280804, [0.34106627])
# (1.2654462, 4.5311747, [0.33960328])
# (1.2327212, 4.434589, [0.33800817])
# (1.2002745, 4.3383512, [0.33627123])
# (1.16813, 4.242495, [0.3343824])
# (1.136313, 4.147055, [0.33233136])
# (1.1048506, 4.05207, [0.33010763])
# (1.0737705, 3.9575791, [0.3277008])
# (1.0431023, 3.863625, [0.32510024])
# (1.0128765, 3.7702544, [0.32229584])
# (0.983125, 3.6775148, [0.31927767])
# (0.9538805, 3.5854573, [0.31603634])
# (0.92517614, 3.4941359, [0.31256318])
# (0.897046, 3.403607, [0.30885047])
# (0.8695246, 3.3139298, [0.30489156])
# (0.8426456, 3.2251647, [0.30068105])
# (0.81644267, 3.1373754, [0.29621515])
# (0.7909491, 3.0506265, [0.29149178])
# (0.7661959, 2.9649842, [0.2865107])
# (0.7422137, 2.8805158, [0.28127366])
# (0.7190303, 2.7972891, [0.2757847])
# (0.6966715, 2.715372, [0.2700501])
# (0.67516005, 2.6348329, [0.26407844])
# (0.6545156, 2.5557375, [0.2578806])
# (0.6347541, 2.4781513, [0.2514697])
# (0.61588824, 2.4021382, [0.24486127])
# (0.59792596, 2.3277583, [0.23807274])
# (0.5808714, 2.2550695, [0.23112342])
# (0.56472445, 2.1841264, [0.22403441])
# (0.5494804, 2.1149786, [0.21682814])
# (0.5351303, 2.0476708, [0.20952801])
# (0.52166116, 1.9822439, [0.20215845])
# (0.5090558, 1.9187325, [0.19474418])
# (0.4972938, 1.8571665, [0.18731022])
# (0.48635072, 1.7975686, [0.17988116])
# (0.4761995, 1.7399564, [0.17248136])
# (0.4668103, 1.6843411, [0.1651342])
# (0.458151, 1.6307279, [0.15786216])
# (0.45018795, 1.5791162, [0.15068641])
# (0.44288585, 1.5294993, [0.14362666])
# (0.4362086, 1.4818648, [0.13670102])
# (0.43011972, 1.436195, [0.1299259])
# (0.4245824, 1.3924668, [0.1233159])
# (0.41956005, 1.350652, [0.116883725])
# (0.41501686, 1.3107188, [0.11064039])
# (0.4109176, 1.2726308, [0.10459499])
# (0.40722832, 1.2363478, [0.09875485])
# (0.40391618, 1.2018268, [0.09312571])
# (0.40094978, 1.1690217, [0.08771158])
# (0.39829943, 1.137884, [0.08251504])
# (0.39593682, 1.1083632, [0.07753727])
# (0.3938356, 1.0804065, [0.07277806])
# (0.3919709, 1.0539613, [0.068236254])
# (0.39031982, 1.0289729, [0.06390953])
# (0.38886085, 1.0053859, [0.059794582])
# (0.3875744, 0.9831456, [0.055887517])
# (0.38644236, 0.96219647, [0.05218358])
# (0.3854482, 0.9424835, [0.048677485])
# (0.38457683, 0.9239522, [0.045363516])
# (0.3838145, 0.9065486, [0.042235464])
# (0.38314894, 0.8902198, [0.03928691])
# (0.3825688, 0.874914, [0.036511213])
# (0.38206413, 0.86058015, [0.03390148])
# (0.38162595, 0.84716874, [0.03145078])
# (0.38124603, 0.83463174, [0.029152155])
# (0.3809173, 0.8229225, [0.026998641])
# (0.38063326, 0.811996, [0.024983335])
# (0.38038835, 0.80180854, [0.02309941])
# (0.3801775, 0.79231834, [0.021340167])
# (0.3799962, 0.7834851, [0.019699058])
# (0.37984067, 0.77527016, [0.01816968])
# (0.37970743, 0.7676365, [0.016745828])
# (0.37959343, 0.7605488, [0.015421516])
# (0.37949604, 0.75397336, [0.014190957])
# (0.37941304, 0.74787796, [0.0130485445])
# (0.37934235, 0.7422321, [0.011988955])
# (0.3792823, 0.73700666, [0.011007052])
# (0.3792313, 0.73217416, [0.01009794])
# (0.37918806, 0.7277085, [0.009256963])
# (0.37915152, 0.723585, [0.008479666])
# (0.37912065, 0.7197807, [0.0077619012])
# (0.37909457, 0.71627337, [0.0070996317])
# (0.3790726, 0.71304226, [0.0064890636])
# (0.37905413, 0.7100678, [0.005926611])
# (0.3790386, 0.7073318, [0.0054089194])
# (0.37902564, 0.70481706, [0.004932826])
# (0.3790147, 0.70250756, [0.0044953567])
# (0.3790056, 0.7003879, [0.004093654])
# (0.37899804, 0.6984441, [0.003725118])
# (0.3789917, 0.6966627, [0.0033872344])
# (0.3789864, 0.6950315, [0.0030777263])
# (0.37898204, 0.6935392, [0.0027944741])
# (0.3789784, 0.6921748, [0.0025354195])
# (0.3789754, 0.6909283, [0.002298684])
# (0.3789729, 0.6897903, [0.0020825085])
# (0.37897083, 0.68875223, [0.0018852614])
# (0.37896913, 0.68780607, [0.0017054428])
# (0.3789677, 0.6869441, [0.0015415959])
# (0.3789666, 0.6861597, [0.0013924558])
# (0.37896568, 0.6854463, [0.0012568117])
# (0.37896484, 0.6847981, [0.001133537])
# (0.37896428, 0.6842095, [0.0010215831])
# (0.37896374, 0.6836754, [0.0009199807])
# (0.3789633, 0.6831912, [0.0008278561])
# (0.37896296, 0.68275243, [0.00074437726])
# (0.3789627, 0.6823552, [0.0006687965])
# (0.37896246, 0.68199605, [0.00060044474])
# (0.37896228, 0.68167144, [0.0005386695])
# (0.3789621, 0.6813783, [0.00048287841])
# (0.378962, 0.6811137, [0.0004325189])
# (0.3789619, 0.6808751, [0.00038710318])
# (0.3789618, 0.6806601, [0.0003461776])
# (0.37896177, 0.68046665, [0.000309346])
# (0.37896168, 0.68029267, [0.00027622387])
# (0.3789617, 0.6801362, [0.0002464375])
# (0.37896162, 0.6799957, [0.00021969248])
# (0.3789616, 0.6798696, [0.00019567902])
# (0.3789616, 0.6797565, [0.0001741529])
# (0.3789616, 0.6796552, [0.00015485799])
# (0.3789615, 0.6795645, [0.00013758673])
# (0.37896153, 0.6794834, [0.00012215145])
# (0.37896147, 0.679411, [0.000108362874])
# (0.3789615, 0.6793463, [9.604939e-05])
# (0.3789615, 0.6792886, [8.5063744e-05])
# (0.3789615, 0.67923707, [7.5245975e-05])
# (0.37896153, 0.6791913, [6.652856e-05])
# (0.37896147, 0.6791505, [5.8765057e-05])
# (0.37896147, 0.6791143, [5.1863026e-05])
# (0.37896147, 0.6790821, [4.5733992e-05])
# (0.3789615, 0.67905354, [4.0297164e-05])
# (0.37896147, 0.6790282, [3.5475474e-05])
# (0.3789615, 0.67900574, [3.119558e-05])
# (0.37896147, 0.67898583, [2.7404632e-05])
# (0.37896147, 0.67896825, [2.4055596e-05])
# (0.37896147, 0.67895263, [2.1081418e-05])
# (0.37896147, 0.6789389, [1.846999e-05])
# (0.37896147, 0.6789269, [1.6179867e-05])
# (0.3789615, 0.6789162, [1.4148885e-05])
# (0.37896147, 0.67890686, [1.23670325e-05])
# (0.3789615, 0.67889863, [1.0798918e-05])
# (0.37896147, 0.67889136, [9.413809e-06])
# (0.37896147, 0.67888504, [8.211238e-06])
# (0.37896147, 0.67887944, [7.146038e-06])
# (0.37896147, 0.67887455, [6.21262e-06])
# (0.37896147, 0.67887026, [5.393289e-06])
# (0.37896147, 0.67886657, [4.6927016e-06])
# (0.37896144, 0.6788633, [4.069181e-06])
# (0.37896147, 0.67886037, [3.511319e-06])
# (0.37896147, 0.678858, [3.0582305e-06])
# (0.37896147, 0.6788557, [2.625864e-06])
# (0.37896147, 0.6788539, [2.285e-06])
# (0.37896147, 0.67885214, [1.9469298e-06])
# (0.37896147, 0.6788508, [1.6950071e-06])
# (0.37896147, 0.67884964, [1.46823e-06])
# (0.37896147, 0.67884845, [1.2416858e-06])
# (0.37896147, 0.67884743, [1.0479707e-06])
# (0.37896147, 0.67884684, [9.3574636e-07])
# (0.37896147, 0.67884624, [8.2165934e-07])
# (0.37896147, 0.67884564, [7.082708e-07])
# (0.37896147, 0.67884505, [5.958136e-07])
# (0.37896147, 0.67884445, [4.800968e-07])
# (0.37896147, 0.67884386, [3.676396e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.67884356, [3.0943193e-07])
# (0.37896147, 0.6788435, [2.9895455e-07])
# (0.37896147, 0.6788435, [2.9895455e-07])
# (0.37896147, 0.6788435, [2.9895455e-07])
# (0.37896147, 0.6788435, [2.9895455e-07])
# (0.37896147, 0.6788435, [2.9895455e-07])
# (0.37896147, 0.6788435, [2.9895455e-07])
# (0.37896147, 0.67884344, [2.880115e-07])
# (0.37896147, 0.67884344, [2.880115e-07])
# (0.37896147, 0.67884344, [2.880115e-07])
# (0.37896147, 0.67884344, [2.880115e-07])
# (0.37896147, 0.67884344, [2.880115e-07])
# (0.37896147, 0.67884344, [2.880115e-07])
# (0.37896147, 0.67884344, [2.880115e-07])
# (0.37896144, 0.6788434, [2.7706847e-07])
# (0.37896144, 0.6788434, [2.7706847e-07])
# (0.37896144, 0.6788434, [2.7706847e-07])
# (0.37896144, 0.6788434, [2.7706847e-07])
# (0.37896144, 0.6788434, [2.7706847e-07])
# (0.37896144, 0.6788434, [2.7706847e-07])
# (0.37896144, 0.6788434, [2.7706847e-07])
# (0.37896144, 0.6788434, [2.7706847e-07])
# (0.3789615, 0.6788433, [2.651941e-07])
# (0.3789615, 0.6788433, [2.651941e-07])
# (0.3789615, 0.6788433, [2.651941e-07])
# (0.3789615, 0.6788433, [2.651941e-07])
# (0.3789615, 0.6788433, [2.651941e-07])
# (0.3789615, 0.6788433, [2.651941e-07])
# (0.3789615, 0.6788433, [2.651941e-07])
# (0.3789615, 0.6788433, [2.651941e-07])
# (0.3789615, 0.67884326, [2.5401823e-07])
# (0.3789615, 0.67884326, [2.5401823e-07])
# (0.3789615, 0.67884326, [2.5401823e-07])
# (0.3789615, 0.67884326, [2.5401823e-07])
# (0.3789615, 0.67884326, [2.5401823e-07])
# (0.3789615, 0.67884326, [2.5401823e-07])
# (0.3789615, 0.67884326, [2.5401823e-07])
# (0.3789615, 0.67884326, [2.5401823e-07])
# (0.3789615, 0.6788432, [2.423767e-07])
# (0.3789615, 0.6788432, [2.423767e-07])
# (0.3789615, 0.6788432, [2.423767e-07])
# (0.3789615, 0.6788432, [2.423767e-07])
# (0.3789615, 0.6788432, [2.423767e-07])
# (0.3789615, 0.6788432, [2.423767e-07])
# (0.3789615, 0.6788432, [2.423767e-07])
# (0.3789615, 0.6788432, [2.423767e-07])
# (0.3789615, 0.6788432, [2.423767e-07])
# (0.3789615, 0.67884314, [2.3003668e-07])
# (0.3789615, 0.67884314, [2.3003668e-07])
# (0.3789615, 0.67884314, [2.3003668e-07])
# (0.3789615, 0.67884314, [2.3003668e-07])
# (0.3789615, 0.67884314, [2.3003668e-07])
# (0.3789615, 0.67884314, [2.3003668e-07])
# (0.3789615, 0.67884314, [2.3003668e-07])
# (0.3789615, 0.67884314, [2.3003668e-07])
# (0.3789615, 0.67884314, [2.3003668e-07])
# (0.3789615, 0.67884314, [2.3003668e-07])
# (0.3789615, 0.6788431, [2.2025779e-07])
# (0.3789615, 0.6788431, [2.2025779e-07])
# (0.3789615, 0.6788431, [2.2025779e-07])
# (0.3789615, 0.6788431, [2.2025779e-07])
# (0.3789615, 0.6788431, [2.2025779e-07])
# (0.3789615, 0.6788431, [2.2025779e-07])
# (0.3789615, 0.6788431, [2.2025779e-07])
# (0.3789615, 0.6788431, [2.2025779e-07])
# (0.3789615, 0.678843, [2.0978041e-07])
# (0.3789615, 0.678843, [2.0978041e-07])
# (0.3789615, 0.678843, [2.0978041e-07])
# (0.3789615, 0.678843, [2.0978041e-07])
# (0.3789615, 0.678843, [2.0978041e-07])
# (0.3789615, 0.678843, [2.0978041e-07])
# (0.3789615, 0.678843, [2.0978041e-07])
# (0.3789615, 0.678843, [2.0978041e-07])
# (0.3789615, 0.678843, [2.0978041e-07])
# (0.3789615, 0.678843, [2.0978041e-07])
# (0.37896144, 0.67884296, [1.9767322e-07])
# (0.37896144, 0.67884296, [1.9767322e-07])
# (0.37896144, 0.67884296, [1.9767322e-07])
# (0.37896144, 0.67884296, [1.9767322e-07])
# (0.37896144, 0.67884296, [1.9767322e-07])
# (0.37896144, 0.67884296, [1.9767322e-07])
# (0.37896144, 0.67884296, [1.9767322e-07])
# (0.37896144, 0.67884296, [1.9767322e-07])
# (0.37896144, 0.67884296, [1.9767322e-07])
# (0.37896144, 0.67884296, [1.9767322e-07])
# (0.37896144, 0.67884296, [1.9767322e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.37896144, 0.6788429, [1.8626451e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.67884284, [1.7532147e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.3789615, 0.6788428, [1.6321428e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.6788427, [1.5227124e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.37896144, 0.67884266, [1.3946556e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.6788426, [1.2945384e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.67884254, [1.18045136e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788425, [1.0570511e-07])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# (0.3789615, 0.6788424, [9.49949e-08])
# done.
