# %%
from __future__ import print_function
from link_bot_notebooks import notebook_finder
from link_bot_notebooks import toy_problem_optimization_common as tpo
import numpy as np
from itertools import cycle
import matplotlib.pyplot as plt
np.set_printoptions(precision=6)
# Out:
# importing Jupyter notebook from /home/pmitrano/catkin_ws/src/link_bot/link_bot_notebooks/src/link_bot_notebooks/toy_problem_optimization_common.ipynb

# %%
dataset = "../../../link_bot_teleop/data/straight_pulls.txt"
goal = np.zeros((6,1))
data = tpo.load_train(dataset, n_steps=1, N=6, L=2, extract_func=tpo.link_pos_vel_extractor2(6))

# %%
example_idx = 4
traj = data[:, :, example_idx]
vx = traj[0][6]
vy = traj[0][7]
s = traj[0][[0, 1]]
s_true = traj[1][[0, 1]]
s_expected = s + np.array([vx, vy]) * 0.5
d_true = s_true - s
d_expected = s_expected - s
xy_error = s_true - s_expected
no_dynamics_error = s_true - s
xy_error_d = np.linalg.norm(xy_error)
no_dynamics_error_d = np.linalg.norm(no_dynamics_error)
print('speed', np.hypot(vx, vy))
print('distance error for xy model', xy_error_d)
print('distance error for no dynamics model', no_dynamics_error_d)
if xy_error_d > no_dynamics_error_d:
    print(":'(")
plt.scatter(s[0], s[1], s=100, c='r')
plt.plot([s[0], s_true[0]], [s[1], s_true[1]], label='gazebo')
plt.plot([s[0], s_expected[0]], [s[1], s_expected[1]], label='expected')
plt.legend();
# Out:
# speed 1.3050182223702287
# distance error for xy model 0.13845754383796816
# distance error for no dynamics model 0.5590068764903326

# %%
f = 0
for i in range(data.shape[2]):
    traj = data[:, :, i]
    vx = traj[0][6]
    vy = traj[0][7]
    s = traj[0][[0, 1]]
    s_true = traj[1][[0, 1]]
    s_expected = s + np.array([vx, vy]) * 0.5
    d_true = s_true - s
    d_expected = s_expected - s
    xy_error = s_true - s_expected
    no_dynamics_error = s_true - s
    xy_error_d = np.linalg.norm(xy_error)
    no_dynamics_error_d = np.linalg.norm(no_dynamics_error)
    if xy_error_d > no_dynamics_error_d:
        f+=1
        print("NO DYNAMICS MODEL DOES BETTER for example ", i)
        print('\tspeed', np.hypot(vx, vy))
        print('\tdistance error for xy model', xy_error_d)
        print('\tdistance error for no dynamics model', no_dynamics_error_d)
#         plt.scatter(s[0], s[1], s=100, c='r')
#         plt.plot([s[0], s_true[0]], [s[1], s_true[1]], label='gazebo')
#         plt.plot([s[0], s_expected[0]], [s[1], s_expected[1]], label='expected')
#         plt.legend();
print(f)
# Out:
# NO DYNAMICS MODEL DOES BETTER for example  3
# 	speed 0.13069394955231106
# 	distance error for xy model 0.06472500533315066
# 	distance error for no dynamics model 0.0006507589519902562
# NO DYNAMICS MODEL DOES BETTER for example  10
# 	speed 0.09033820744390475
# 	distance error for xy model 0.04499037743235608
# 	distance error for no dynamics model 0.0001873332732189332
# NO DYNAMICS MODEL DOES BETTER for example  11
# 	speed 0.19338944648228
# 	distance error for xy model 0.0743274105476037
# 	distance error for no dynamics model 0.023259770226657244
# NO DYNAMICS MODEL DOES BETTER for example  13
# 	speed 0.24196427682749438
# 	distance error for xy model 0.07728775778812973
# 	distance error for no dynamics model 0.04601298206604993
# NO DYNAMICS MODEL DOES BETTER for example  15
# 	speed 0.2072744270229207
# 	distance error for xy model 0.08058772498460025
# 	distance error for no dynamics model 0.026638670681577124
# NO DYNAMICS MODEL DOES BETTER for example  16
# 	speed 0.1456519136895919
# 	distance error for xy model 0.06970365847039385
# 	distance error for no dynamics model 0.003445497095856204
# NO DYNAMICS MODEL DOES BETTER for example  18
# 	speed 0.05878168838148101
# 	distance error for xy model 0.02934330309731615
# 	distance error for no dynamics model 4.7754197502131034e-05
# NO DYNAMICS MODEL DOES BETTER for example  19
# 	speed 0.17809157843136608
# 	distance error for xy model 0.07519733499442416
# 	distance error for no dynamics model 0.01451390215110002
# NO DYNAMICS MODEL DOES BETTER for example  21
# 	speed 0.1409107661376625
# 	distance error for xy model 0.06669638030101412
# 	distance error for no dynamics model 0.003785620288386814
# NO DYNAMICS MODEL DOES BETTER for example  23
# 	speed 0.27478704301067525
# 	distance error for xy model 0.07584795706995232
# 	distance error for no dynamics model 0.0646180529605376
# NO DYNAMICS MODEL DOES BETTER for example  24
# 	speed 0.007043214288820598
# 	distance error for xy model 0.0035142775749004256
# 	distance error for no dynamics model 7.340184645291246e-06
# NO DYNAMICS MODEL DOES BETTER for example  39
# 	speed 0.10375049318270706
# 	distance error for xy model 0.051700143941170035
# 	distance error for no dynamics model 0.00018671800211081597
# NO DYNAMICS MODEL DOES BETTER for example  42
# 	speed 0.08150698250888044
# 	distance error for xy model 0.04062139458809332
# 	distance error for no dynamics model 0.00013241531096138485
# NO DYNAMICS MODEL DOES BETTER for example  44
# 	speed 0.04775839429696177
# 	distance error for xy model 0.023857586287354928
# 	distance error for no dynamics model 2.1720793274705292e-05
# NO DYNAMICS MODEL DOES BETTER for example  47
# 	speed 0.3147656234626832
# 	distance error for xy model 0.09997403747058774
# 	distance error for no dynamics model 0.07859025606401347
# NO DYNAMICS MODEL DOES BETTER for example  50
# 	speed 0.2694055163394522
# 	distance error for xy model 0.09678933448960346
# 	distance error for no dynamics model 0.04055816153516499
# NO DYNAMICS MODEL DOES BETTER for example  60
# 	speed 0.19810215951772997
# 	distance error for xy model 0.0642195884127534
# 	distance error for no dynamics model 0.035145395660899234
# NO DYNAMICS MODEL DOES BETTER for example  61
# 	speed 0.27491975432111787
# 	distance error for xy model 0.07872477634402746
# 	distance error for no dynamics model 0.06892093212123418
# NO DYNAMICS MODEL DOES BETTER for example  63
# 	speed 0.12513365316302782
# 	distance error for xy model 0.06225782133717311
# 	distance error for no dynamics model 0.0003142930750465119
# NO DYNAMICS MODEL DOES BETTER for example  70
# 	speed 0.019855286638349234
# 	distance error for xy model 0.009921140527875473
# 	distance error for no dynamics model 6.642634760018049e-06
# NO DYNAMICS MODEL DOES BETTER for example  72
# 	speed 0.2053504075283984
# 	distance error for xy model 0.08965769533915263
# 	distance error for no dynamics model 0.0140194468265892
# NO DYNAMICS MODEL DOES BETTER for example  75
# 	speed 0.12165208498199513
# 	distance error for xy model 0.060421131623970205
# 	distance error for no dynamics model 0.0004131931037508692
# NO DYNAMICS MODEL DOES BETTER for example  76
# 	speed 0.08014077268023789
# 	distance error for xy model 0.040032421090765685
# 	distance error for no dynamics model 3.856979444134047e-05
# NO DYNAMICS MODEL DOES BETTER for example  77
# 	speed 0.22041996810056258
# 	distance error for xy model 0.07006778075815813
# 	distance error for no dynamics model 0.04065497595462631
# NO DYNAMICS MODEL DOES BETTER for example  85
# 	speed 0.06691845188117113
# 	distance error for xy model 0.03331909452853169
# 	distance error for no dynamics model 0.00014039464614314952
# NO DYNAMICS MODEL DOES BETTER for example  87
# 	speed 0.053043653633236376
# 	distance error for xy model 0.026503061150174125
# 	distance error for no dynamics model 1.8872298675988837e-05
# NO DYNAMICS MODEL DOES BETTER for example  93
# 	speed 0.24080823372788462
# 	distance error for xy model 0.07495485158320736
# 	distance error for no dynamics model 0.04558748298980349
# NO DYNAMICS MODEL DOES BETTER for example  96
# 	speed 0.2391216951734339
# 	distance error for xy model 0.07806271317138322
# 	distance error for no dynamics model 0.047487067696784145
# NO DYNAMICS MODEL DOES BETTER for example  99
# 	speed 0.2778484878542759
# 	distance error for xy model 0.07511017266873077
# 	distance error for no dynamics model 0.0644301138613824
# NO DYNAMICS MODEL DOES BETTER for example  105
# 	speed 0.24443163906990806
# 	distance error for xy model 0.0870740785412032
# 	distance error for no dynamics model 0.04362928639793176
# NO DYNAMICS MODEL DOES BETTER for example  106
# 	speed 0.0979563107276703
# 	distance error for xy model 0.0488621138636697
# 	distance error for no dynamics model 0.00011609098277024624
# NO DYNAMICS MODEL DOES BETTER for example  110
# 	speed 0.06901096633094539
# 	distance error for xy model 0.034460321949944445
# 	distance error for no dynamics model 4.5440259768720645e-05
# NO DYNAMICS MODEL DOES BETTER for example  126
# 	speed 0.07303544396329281
# 	distance error for xy model 0.03648984971062206
# 	distance error for no dynamics model 2.7905057336953583e-05
# NO DYNAMICS MODEL DOES BETTER for example  133
# 	speed 0.17355484999064047
# 	distance error for xy model 0.06861921938314315
# 	distance error for no dynamics model 0.01886629144157908
# NO DYNAMICS MODEL DOES BETTER for example  137
# 	speed 0.14586438844863697
# 	distance error for xy model 0.06689327708761873
# 	distance error for no dynamics model 0.006232615197397545
# NO DYNAMICS MODEL DOES BETTER for example  138
# 	speed 0.1363285980486142
# 	distance error for xy model 0.0661813408242258
# 	distance error for no dynamics model 0.0020616196426739134
# NO DYNAMICS MODEL DOES BETTER for example  142
# 	speed 0.05405072614285422
# 	distance error for xy model 0.02698835116261587
# 	distance error for no dynamics model 3.706649495495911e-05
# NO DYNAMICS MODEL DOES BETTER for example  145
# 	speed 0.11473015354542809
# 	distance error for xy model 0.056849274636414225
# 	distance error for no dynamics model 0.0006826051667140079
# NO DYNAMICS MODEL DOES BETTER for example  146
# 	speed 0.0899164473743599
# 	distance error for xy model 0.04481171764696414
# 	distance error for no dynamics model 0.0001465079529703029
# NO DYNAMICS MODEL DOES BETTER for example  150
# 	speed 0.09481142750794597
# 	distance error for xy model 0.047074767447194375
# 	distance error for no dynamics model 0.00034642990878547205
# NO DYNAMICS MODEL DOES BETTER for example  157
# 	speed 0.3628525563022272
# 	distance error for xy model 0.09870470037315873
# 	distance error for no dynamics model 0.09683777904067171
# NO DYNAMICS MODEL DOES BETTER for example  163
# 	speed 0.08780238335333818
# 	distance error for xy model 0.04343884030728744
# 	distance error for no dynamics model 0.0007033084377324531
# NO DYNAMICS MODEL DOES BETTER for example  165
# 	speed 0.4068781151427962
# 	distance error for xy model 0.11095106104807356
# 	distance error for no dynamics model 0.09575199167520661
# NO DYNAMICS MODEL DOES BETTER for example  172
# 	speed 0.04378535227336988
# 	distance error for xy model 0.02186642507000076
# 	distance error for no dynamics model 2.6359466297849362e-05
# NO DYNAMICS MODEL DOES BETTER for example  175
# 	speed 0.12796638467805505
# 	distance error for xy model 0.06368507379002447
# 	distance error for no dynamics model 0.0003017006524418879
# NO DYNAMICS MODEL DOES BETTER for example  176
# 	speed 0.09922419317543206
# 	distance error for xy model 0.04919024910933097
# 	distance error for no dynamics model 0.0004231126026281133
# NO DYNAMICS MODEL DOES BETTER for example  178
# 	speed 0.2993942131801715
# 	distance error for xy model 0.09669770211609563
# 	distance error for no dynamics model 0.06081696229872406
# NO DYNAMICS MODEL DOES BETTER for example  184
# 	speed 0.23976793028128696
# 	distance error for xy model 0.09885772595042884
# 	distance error for no dynamics model 0.021150797579235086
# NO DYNAMICS MODEL DOES BETTER for example  185
# 	speed 0.26786995208648445
# 	distance error for xy model 0.07809185537156325
# 	distance error for no dynamics model 0.05587129880255869
# NO DYNAMICS MODEL DOES BETTER for example  196
# 	speed 0.1130386036250105
# 	distance error for xy model 0.055945451022142004
# 	distance error for no dynamics model 0.0005767826111584378
# NO DYNAMICS MODEL DOES BETTER for example  203
# 	speed 0.3186515419410615
# 	distance error for xy model 0.09903669357507885
# 	distance error for no dynamics model 0.06845760480747286
# NO DYNAMICS MODEL DOES BETTER for example  205
# 	speed 0.09533066225423764
# 	distance error for xy model 0.04756837157871575
# 	distance error for no dynamics model 0.00010318615813253347
# NO DYNAMICS MODEL DOES BETTER for example  207
# 	speed 0.17349280785751997
# 	distance error for xy model 0.08126246166250722
# 	distance error for no dynamics model 0.006951251968200224
# NO DYNAMICS MODEL DOES BETTER for example  217
# 	speed 0.2782768462847644
# 	distance error for xy model 0.09475230494935867
# 	distance error for no dynamics model 0.05965210079183464
# NO DYNAMICS MODEL DOES BETTER for example  225
# 	speed 0.08907478200868385
# 	distance error for xy model 0.044291613196324436
# 	distance error for no dynamics model 0.0002543612251701183
# NO DYNAMICS MODEL DOES BETTER for example  227
# 	speed 0.0853158887180332
# 	distance error for xy model 0.042580460691786226
# 	distance error for no dynamics model 7.757903437997913e-05
# NO DYNAMICS MODEL DOES BETTER for example  231
# 	speed 0.05783586908849753
# 	distance error for xy model 0.028881946528768965
# 	distance error for no dynamics model 3.6671558499980294e-05
# NO DYNAMICS MODEL DOES BETTER for example  232
# 	speed 0.06438628591324802
# 	distance error for xy model 0.032159048719262825
# 	distance error for no dynamics model 3.4608242391761635e-05
# NO DYNAMICS MODEL DOES BETTER for example  242
# 	speed 0.2647490833335902
# 	distance error for xy model 0.07293099843774745
# 	distance error for no dynamics model 0.05992844105693855
# NO DYNAMICS MODEL DOES BETTER for example  248
# 	speed 0.14651455117158618
# 	distance error for xy model 0.06626343543111606
# 	distance error for no dynamics model 0.007016441773675245
# NO DYNAMICS MODEL DOES BETTER for example  251
# 	speed 0.04599157248857688
# 	distance error for xy model 0.022981706999326793
# 	distance error for no dynamics model 1.4102543904778433e-05
# NO DYNAMICS MODEL DOES BETTER for example  252
# 	speed 0.1612088516532068
# 	distance error for xy model 0.07769002350352246
# 	distance error for no dynamics model 0.003155315212313508
# NO DYNAMICS MODEL DOES BETTER for example  256
# 	speed 0.27802288046907425
# 	distance error for xy model 0.06965150997798429
# 	distance error for no dynamics model 0.06960955903821046
# NO DYNAMICS MODEL DOES BETTER for example  257
# 	speed 0.1021396488631599
# 	distance error for xy model 0.05085086123940737
# 	distance error for no dynamics model 0.00022073978576687587
# NO DYNAMICS MODEL DOES BETTER for example  262
# 	speed 0.02026305994007832
# 	distance error for xy model 0.01011250472605382
# 	distance error for no dynamics model 2.7064627386590684e-05
# NO DYNAMICS MODEL DOES BETTER for example  265
# 	speed 0.017032692768288837
# 	distance error for xy model 0.00850743351751997
# 	distance error for no dynamics model 9.802418718383307e-06
# NO DYNAMICS MODEL DOES BETTER for example  268
# 	speed 0.16335560826198933
# 	distance error for xy model 0.06726399482688464
# 	distance error for no dynamics model 0.01555333880098334
# NO DYNAMICS MODEL DOES BETTER for example  272
# 	speed 0.18041601746920444
# 	distance error for xy model 0.08774652379663339
# 	distance error for no dynamics model 0.0027006276049502615
# NO DYNAMICS MODEL DOES BETTER for example  276
# 	speed 0.09911139577750788
# 	distance error for xy model 0.04918472638137901
# 	distance error for no dynamics model 0.0003709902418705637
# NO DYNAMICS MODEL DOES BETTER for example  280
# 	speed 0.16578344107899087
# 	distance error for xy model 0.06975607140331962
# 	distance error for no dynamics model 0.013551656619491755
# NO DYNAMICS MODEL DOES BETTER for example  294
# 	speed 0.2033226496627596
# 	distance error for xy model 0.07292705088428486
# 	distance error for no dynamics model 0.031213425164992294
# NO DYNAMICS MODEL DOES BETTER for example  305
# 	speed 0.17792327754864884
# 	distance error for xy model 0.06463506577108163
# 	distance error for no dynamics model 0.0243621622900918
# NO DYNAMICS MODEL DOES BETTER for example  307
# 	speed 0.15710416002193991
# 	distance error for xy model 0.07554000249481896
# 	distance error for no dynamics model 0.0031729575623286855
# NO DYNAMICS MODEL DOES BETTER for example  309
# 	speed 0.09403329303546083
# 	distance error for xy model 0.04686157829634188
# 	distance error for no dynamics model 0.0001602876105025951
# NO DYNAMICS MODEL DOES BETTER for example  310
# 	speed 0.2268453374611275
# 	distance error for xy model 0.06797768649369289
# 	distance error for no dynamics model 0.047251121901664826
# NO DYNAMICS MODEL DOES BETTER for example  313
# 	speed 0.17837541321902034
# 	distance error for xy model 0.08296577691415198
# 	distance error for no dynamics model 0.007322398143451196
# NO DYNAMICS MODEL DOES BETTER for example  317
# 	speed 0.0536140237507256
# 	distance error for xy model 0.026719983469984127
# 	distance error for no dynamics model 8.750860707819359e-05
# NO DYNAMICS MODEL DOES BETTER for example  320
# 	speed 0.15347522383139134
# 	distance error for xy model 0.06419900293933743
# 	distance error for no dynamics model 0.012662245903360325
# NO DYNAMICS MODEL DOES BETTER for example  324
# 	speed 0.15035015613618458
# 	distance error for xy model 0.0611293139336139
# 	distance error for no dynamics model 0.014052458462735066
# NO DYNAMICS MODEL DOES BETTER for example  326
# 	speed 0.14671524221857912
# 	distance error for xy model 0.07275360623021285
# 	distance error for no dynamics model 0.0006761163226039289
# NO DYNAMICS MODEL DOES BETTER for example  327
# 	speed 0.08060032103060306
# 	distance error for xy model 0.04009447672503315
# 	distance error for no dynamics model 0.00023120541098453333
# NO DYNAMICS MODEL DOES BETTER for example  331
# 	speed 0.09768220282322759
# 	distance error for xy model 0.04828270375886316
# 	distance error for no dynamics model 0.0005651109427217697
# NO DYNAMICS MODEL DOES BETTER for example  338
# 	speed 0.1129159197491017
# 	distance error for xy model 0.05613437416745094
# 	distance error for no dynamics model 0.00034753191223205746
# NO DYNAMICS MODEL DOES BETTER for example  351
# 	speed 0.03778543393575923
# 	distance error for xy model 0.018812033935726093
# 	distance error for no dynamics model 9.524079145972555e-05
# NO DYNAMICS MODEL DOES BETTER for example  353
# 	speed 0.09011694646988694
# 	distance error for xy model 0.04470939210910272
# 	distance error for no dynamics model 0.0003491813711281777
# NO DYNAMICS MODEL DOES BETTER for example  357
# 	speed 0.16002367020407016
# 	distance error for xy model 0.07980952893027657
# 	distance error for no dynamics model 0.00020633147379577198
# NO DYNAMICS MODEL DOES BETTER for example  366
# 	speed 0.2946764877314309
# 	distance error for xy model 0.09039838981147054
# 	distance error for no dynamics model 0.06720874674889897
# NO DYNAMICS MODEL DOES BETTER for example  373
# 	speed 0.045639773005508866
# 	distance error for xy model 0.022781248947786117
# 	distance error for no dynamics model 3.8656754098970684e-05
# NO DYNAMICS MODEL DOES BETTER for example  385
# 	speed 0.290986196400296
# 	distance error for xy model 0.08738679251898009
# 	distance error for no dynamics model 0.06431734759181346
# NO DYNAMICS MODEL DOES BETTER for example  393
# 	speed 0.061312290141027466
# 	distance error for xy model 0.03056418279233465
# 	distance error for no dynamics model 9.221785923897123e-05
# NO DYNAMICS MODEL DOES BETTER for example  396
# 	speed 0.05140056052834425
# 	distance error for xy model 0.025664450303458878
# 	distance error for no dynamics model 3.844231418550534e-05
# NO DYNAMICS MODEL DOES BETTER for example  399
# 	speed 0.21987560422658503
# 	distance error for xy model 0.07400215623035478
# 	distance error for no dynamics model 0.044902466813442926
# NO DYNAMICS MODEL DOES BETTER for example  401
# 	speed 0.15974297065659054
# 	distance error for xy model 0.07911053309269687
# 	distance error for no dynamics model 0.0008665185991726244
# NO DYNAMICS MODEL DOES BETTER for example  404
# 	speed 0.16833647374243277
# 	distance error for xy model 0.07593659003476501
# 	distance error for no dynamics model 0.008993567455473203
# NO DYNAMICS MODEL DOES BETTER for example  411
# 	speed 0.11698922681373686
# 	distance error for xy model 0.0577411068621583
# 	distance error for no dynamics model 0.0007746972627687474
# NO DYNAMICS MODEL DOES BETTER for example  412
# 	speed 0.2296453452535842
# 	distance error for xy model 0.07231378040181095
# 	distance error for no dynamics model 0.0427630766197205
# NO DYNAMICS MODEL DOES BETTER for example  420
# 	speed 0.04916385194004508
# 	distance error for xy model 0.024556118112404303
# 	distance error for no dynamics model 2.585407981490429e-05
# NO DYNAMICS MODEL DOES BETTER for example  422
# 	speed 0.2160878116362634
# 	distance error for xy model 0.06265928221263808
# 	distance error for no dynamics model 0.045828974641231035
# NO DYNAMICS MODEL DOES BETTER for example  425
# 	speed 0.04941817279684857
# 	distance error for xy model 0.024660362019032347
# 	distance error for no dynamics model 5.126883727456041e-05
# NO DYNAMICS MODEL DOES BETTER for example  426
# 	speed 0.3468824294695327
# 	distance error for xy model 0.10307944449091615
# 	distance error for no dynamics model 0.09136146119956447
# NO DYNAMICS MODEL DOES BETTER for example  428
# 	speed 0.3062164132705891
# 	distance error for xy model 0.09508903805978645
# 	distance error for no dynamics model 0.08011700914233093
# NO DYNAMICS MODEL DOES BETTER for example  430
# 	speed 0.325918458506747
# 	distance error for xy model 0.08867264191482373
# 	distance error for no dynamics model 0.07551712598458488
# NO DYNAMICS MODEL DOES BETTER for example  431
# 	speed 0.25011237016704396
# 	distance error for xy model 0.07232152289192073
# 	distance error for no dynamics model 0.05514241795703331
# NO DYNAMICS MODEL DOES BETTER for example  433
# 	speed 0.14118365412827544
# 	distance error for xy model 0.07008711325695235
# 	distance error for no dynamics model 0.0005058071724461528
# NO DYNAMICS MODEL DOES BETTER for example  434
# 	speed 0.12067277330610077
# 	distance error for xy model 0.05981141906884685
# 	distance error for no dynamics model 0.0005381726622848752
# NO DYNAMICS MODEL DOES BETTER for example  436
# 	speed 0.013589999283577348
# 	distance error for xy model 0.006787706574704013
# 	distance error for no dynamics model 7.717693076765435e-06
# NO DYNAMICS MODEL DOES BETTER for example  443
# 	speed 0.2567580722327378
# 	distance error for xy model 0.07700511635926367
# 	distance error for no dynamics model 0.0618457814668677
# NO DYNAMICS MODEL DOES BETTER for example  445
# 	speed 0.10890009982140798
# 	distance error for xy model 0.053317656728708585
# 	distance error for no dynamics model 0.0011362795642997294
# NO DYNAMICS MODEL DOES BETTER for example  446
# 	speed 0.3289190778046013
# 	distance error for xy model 0.10104135789829936
# 	distance error for no dynamics model 0.07137438994240303
# NO DYNAMICS MODEL DOES BETTER for example  451
# 	speed 0.042544401345112615
# 	distance error for xy model 0.021227652549175042
# 	distance error for no dynamics model 5.491056803986433e-05
# NO DYNAMICS MODEL DOES BETTER for example  459
# 	speed 0.28104135213948417
# 	distance error for xy model 0.08704578496619202
# 	distance error for no dynamics model 0.0737199524649783
# NO DYNAMICS MODEL DOES BETTER for example  460
# 	speed 0.3029496426363048
# 	distance error for xy model 0.08608855637875276
# 	distance error for no dynamics model 0.08129426601491999
# NO DYNAMICS MODEL DOES BETTER for example  463
# 	speed 0.2719014932217636
# 	distance error for xy model 0.07722068496558476
# 	distance error for no dynamics model 0.07099167665683323
# NO DYNAMICS MODEL DOES BETTER for example  464
# 	speed 0.19972228730365227
# 	distance error for xy model 0.06459128426211959
# 	distance error for no dynamics model 0.038535402954930686
# NO DYNAMICS MODEL DOES BETTER for example  469
# 	speed 0.3375023920157431
# 	distance error for xy model 0.10675067332326672
# 	distance error for no dynamics model 0.08395920014291317
# NO DYNAMICS MODEL DOES BETTER for example  470
# 	speed 0.12529588283297555
# 	distance error for xy model 0.06196333560213617
# 	distance error for no dynamics model 0.0007434138185934278
# NO DYNAMICS MODEL DOES BETTER for example  479
# 	speed 0.194643933852572
# 	distance error for xy model 0.06585665095149197
# 	distance error for no dynamics model 0.03178009800432348
# NO DYNAMICS MODEL DOES BETTER for example  480
# 	speed 0.013871991335549063
# 	distance error for xy model 0.006735743439410726
# 	distance error for no dynamics model 0.00022401378051980074
# NO DYNAMICS MODEL DOES BETTER for example  482
# 	speed 0.17631891113409526
# 	distance error for xy model 0.058520523789513126
# 	distance error for no dynamics model 0.0312613959748537
# NO DYNAMICS MODEL DOES BETTER for example  484
# 	speed 0.09056922303839461
# 	distance error for xy model 0.04509479210192617
# 	distance error for no dynamics model 0.00019117897922434586
# NO DYNAMICS MODEL DOES BETTER for example  486
# 	speed 0.013926675758890616
# 	distance error for xy model 0.006872390099555715
# 	distance error for no dynamics model 9.103433141059887e-05
# NO DYNAMICS MODEL DOES BETTER for example  490
# 	speed 0.24948692057945804
# 	distance error for xy model 0.07572087614467063
# 	distance error for no dynamics model 0.04970850881762081
# NO DYNAMICS MODEL DOES BETTER for example  491
# 	speed 0.24310947754494822
# 	distance error for xy model 0.07302915007932674
# 	distance error for no dynamics model 0.05167998665896717
# NO DYNAMICS MODEL DOES BETTER for example  492
# 	speed 0.1134160095976266
# 	distance error for xy model 0.05583010139184436
# 	distance error for no dynamics model 0.0009991017262180005
# NO DYNAMICS MODEL DOES BETTER for example  494
# 	speed 0.26449936119673373
# 	distance error for xy model 0.08690936704831188
# 	distance error for no dynamics model 0.04919260644291919
# NO DYNAMICS MODEL DOES BETTER for example  501
# 	speed 0.2545171733611048
# 	distance error for xy model 0.09202771083452355
# 	distance error for no dynamics model 0.03625528181369185
# NO DYNAMICS MODEL DOES BETTER for example  506
# 	speed 0.09283375326434362
# 	distance error for xy model 0.04599848425289597
# 	distance error for no dynamics model 0.0005117136615831085
# NO DYNAMICS MODEL DOES BETTER for example  512
# 	speed 0.07392788861033779
# 	distance error for xy model 0.036635321867192525
# 	distance error for no dynamics model 0.0003300312054086861
# NO DYNAMICS MODEL DOES BETTER for example  513
# 	speed 0.00011054914965913376
# 	distance error for xy model 6.463176776956545e-05
# 	distance error for no dynamics model 1.0108330925692137e-05
# NO DYNAMICS MODEL DOES BETTER for example  514
# 	speed 0.1724282244556723
# 	distance error for xy model 0.07306997278287777
# 	distance error for no dynamics model 0.013443958241967067
# NO DYNAMICS MODEL DOES BETTER for example  516
# 	speed 0.21596480114307254
# 	distance error for xy model 0.0849144784164303
# 	distance error for no dynamics model 0.023746791187702235
# NO DYNAMICS MODEL DOES BETTER for example  522
# 	speed 0.34589195498808223
# 	distance error for xy model 0.09221122632689725
# 	distance error for no dynamics model 0.08754599556462521
# NO DYNAMICS MODEL DOES BETTER for example  527
# 	speed 0.27630645977824075
# 	distance error for xy model 0.07746360511455296
# 	distance error for no dynamics model 0.06504169173674346
# NO DYNAMICS MODEL DOES BETTER for example  533
# 	speed 0.17238652498234797
# 	distance error for xy model 0.062202063907367586
# 	distance error for no dynamics model 0.024703400382498235
# NO DYNAMICS MODEL DOES BETTER for example  536
# 	speed 0.337165992588997
# 	distance error for xy model 0.09600769881784667
# 	distance error for no dynamics model 0.087415257538081
# NO DYNAMICS MODEL DOES BETTER for example  538
# 	speed 0.05011093892268015
# 	distance error for xy model 0.024819478269044452
# 	distance error for no dynamics model 0.00028445821294486955
# NO DYNAMICS MODEL DOES BETTER for example  546
# 	speed 0.17188225451340855
# 	distance error for xy model 0.0714588622138053
# 	distance error for no dynamics model 0.01500190225298789
# NO DYNAMICS MODEL DOES BETTER for example  549
# 	speed 0.17071229703535734
# 	distance error for xy model 0.06666079760984064
# 	distance error for no dynamics model 0.019062538680248316
# NO DYNAMICS MODEL DOES BETTER for example  552
# 	speed 0.10178372655566319
# 	distance error for xy model 0.050614795537571956
# 	distance error for no dynamics model 0.00028075060523732653
# NO DYNAMICS MODEL DOES BETTER for example  553
# 	speed 0.0754365947210836
# 	distance error for xy model 0.03769935625144157
# 	distance error for no dynamics model 1.9213128463870374e-05
# NO DYNAMICS MODEL DOES BETTER for example  558
# 	speed 0.19667434345071838
# 	distance error for xy model 0.06795632126649544
# 	distance error for no dynamics model 0.03043718494380782
# NO DYNAMICS MODEL DOES BETTER for example  560
# 	speed 0.008242226713744083
# 	distance error for xy model 0.004114054007857236
# 	distance error for no dynamics model 7.2532802371801485e-06
# NO DYNAMICS MODEL DOES BETTER for example  572
# 	speed 0.02351417407487089
# 	distance error for xy model 0.011720030894991051
# 	distance error for no dynamics model 3.888614556641643e-05
# NO DYNAMICS MODEL DOES BETTER for example  587
# 	speed 0.33973691691153246
# 	distance error for xy model 0.09357041295423023
# 	distance error for no dynamics model 0.09265185859055915
# NO DYNAMICS MODEL DOES BETTER for example  592
# 	speed 0.15120677534193083
# 	distance error for xy model 0.07507783332533725
# 	distance error for no dynamics model 0.0005912799190862169
# NO DYNAMICS MODEL DOES BETTER for example  595
# 	speed 0.35042721752937
# 	distance error for xy model 0.10007859628793872
# 	distance error for no dynamics model 0.0811782880256701
# 146
