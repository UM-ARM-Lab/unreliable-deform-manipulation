# %% [markdown]
# # Plot Data

# %%
from __future__ import print_function
from link_bot_notebooks import notebook_finder
from link_bot_notebooks import toy_problem_optimization_common as tpo
import numpy as np
import matplotlib.pyplot as plt
# Out:
# importing Jupyter notebook from /home/pmitrano/catkin_ws/src/link_bot/link_bot_notebooks/src/link_bot_notebooks/toy_problem_optimization_common.ipynb

# %%
dataset = "../../../link_bot_teleop/data/random_speeds.txt"

# %%
goal = np.zeros((6,1))
n, data = tpo.load_train(dataset, N=6, L=2, extract_func=tpo.link_pos_vel_extractor2(6))

# %%
data.shape
# Out:
# (8000, 8)

# %%
plt.figure(figsize=(16,6))
plt.title(r"Full State ($s$)")
plt.plot(data[:, 0], label='x1')
plt.plot(data[:, 1], label='y1')
plt.plot(data[:, 2], label='x2')
plt.plot(data[:, 3], label='y2')
plt.plot(data[:, 4], label='x3')
plt.plot(data[:, 5], label='y3')
plt.ylabel("meters")
plt.xlabel("time (steps)")
plt.legend();

# %%
plt.figure(figsize=(10,10))
plt.title(r"Position of first point")
plt.scatter(data[:, 0], data[:, 1], s=1)
plt.ylabel("x (m)")
plt.xlabel("y (m)")
plt.axis("equal")
plt.legend();

# %%
plt.figure(figsize=(16,6))
plt.title(r"Control Input ($u$)")
plt.plot(data[:, 6], label='vx')
plt.plot(data[:, 7], label='vy')
plt.ylabel("m/s")
plt.xlabel("time (steps)")
plt.legend();
