# %% [markdown]
# # Link Bot in static environment
#
# controlling the velocity of one point
# logging position and velocity now

# %%
from link_bot_notebooks import notebook_finder
import numpy as np
import matplotlib.pyplot as plt
np.set_printoptions(suppress=True, precision=2)
from link_bot_notebooks import toy_problem_optimization_common as tpo
from link_bot_notebooks.toy_problem_optimization_common import BOLD
np.random.seed(0)
# Out:
# importing Jupyter notebook from /home/pmitrano/catkin_ws/src/link_bot/link_bot_notebooks/src/link_bot_notebooks/toy_problem_optimization_common.ipynb

# %%
goal = np.zeros((6, 1))
data = tpo.load_gazebo_data_v3("../../../link_bot_teleop/data/2_link_pos_and_vel_1.txt", goal)

# %%
tpo.plot_gz_data_v2(plt, data)
